# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from collections import Counter, defaultdict
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

# %%
coco = COCO('../dataset/train.json')
base_path = '/opt/ml/detection/dataset'
# Out:
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!

# %%
# 이미지 랜덤 추출

img = coco.loadImgs(imgIds[np.random.randint(0, len(coco.dataset))])[0]
img
# Out:
# {'width': 1024,
#  'height': 1024,
#  'file_name': 'train/0004.jpg',
#  'license': 0,
#  'flickr_url': None,
#  'coco_url': None,
#  'date_captured': '2021-01-01 18:52:38',
#  'id': 4}

# %%
# 이미지 확인

plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(cv2.imread(os.path.join(base_path, img['file_name']))[...,::-1])
plt.show()

# %%
# 이미지의 박스는 무엇인가?

annIds = coco.getAnnIds(imgIds=img['id'], iscrowd=None)
print(annIds)
anns = coco.loadAnns(annIds)
print(anns)
# Out:
# [12, 13, 14, 15, 16, 17]
# [{'image_id': 4, 'category_id': 1, 'area': 14768.88, 'bbox': [567.5, 462.2, 165.2, 89.4], 'iscrowd': 0, 'id': 12, 'segmentation': []}, {'image_id': 4, 'category_id': 1, 'area': 32987.78, 'bbox': [859.4, 411.7, 164.2, 200.9], 'iscrowd': 0, 'id': 13, 'segmentation': []}, {'image_id': 4, 'category_id': 1, 'area': 32747.0, 'bbox': [362.0, 349.7, 130.0, 251.9], 'iscrowd': 0, 'id': 14, 'segmentation': []}, {'image_id': 4, 'category_id': 1, 'area': 54208.4, 'bbox': [392.5, 348.4, 212.0, 255.7], 'iscrowd': 0, 'id': 15, 'segmentation': []}, {'image_id': 4, 'category_id': 1, 'area': 57900.45, 'bbox': [482.2, 491.4, 277.7, 208.5], 'iscrowd': 0, 'id': 16, 'segmentation': []}, {'image_id': 4, 'category_id': 0, 'area': 4523.64, 'bbox': [868.2, 521.7, 101.2, 44.7], 'iscrowd': 0, 'id': 17, 'segmentation': []}]

# %%
# Box 표시

for d in anns:
    d['segmentation'] = []

plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(cv2.imread(os.path.join(base_path, img['file_name']))[...,::-1])
coco.showAnns(anns, draw_bbox=True)
plt.show()

# %% [markdown]
# * Total 4883 images
# * All images are of size 1024 x 1024
# * All files are unique (no duplicate)
#
# * 10 Classes ['General trash',
#  'Paper',
#  'Paper pack',
#  'Metal',
#  'Glass',
#  'Plastic',
#  'Styrofoam',
#  'Plastic bag',
#  'Battery',
#  'Clothing']

# %%
# 이미지당 박스 갯수 분포

# %%
n_annos = [0]*len(coco.getImgIds())

for d in coco.anns.values():
    n_annos[d['image_id']] += 1
    
annos_counter = Counter(n_annos)
counts = [0]*80

for c, n in annos_counter.items():
    counts[c] = n
    
plt.bar(list(range(len(counts))), counts, log=True)
plt.show()

# %%
# 박스의 가로 세로 길이 산포도

# %%
plt.figure(figsize=(10,10))
plt.scatter(w, h, s=2, alpha=0.1)
plt.xlim(0, 1030)
plt.ylim(0, 1030)
plt.xticks([50*i for i in range(1050//50)])
plt.yticks([50*i for i in range(1050//50)])
plt.show()

# %%
# 박스의 모양(비율) 분포 (x축은 log분포)

# %%
w = []
h = []
s = []
r = []

for d in coco.anns.values():
    x1, y1, w1, h1 = d['bbox']
    w.append(w1)
    h.append(h1)
    s.append(w1*h1)
    r.append(w1/h1)

# %%
import numpy as np
plt.figure(figsize=(10,10))
plt.hist(np.log(r), bins=40)
plt.show()

# %% [markdown]
#  => 1:1 비율의 빈도수가 많고 2:1, 1:2 정도면 어느정도 다 커버되는것으로 보인다.

# %%
# 박스의 길이(sqrt(w*h)) 분포

# %%
plt.figure(figsize=(10,10))
plt.hist([x**0.5 for x in s], bins=100)
plt.show()

# %%
# 아래는 그냥 train/val split 과정

# %%
import json

with open('../dataset/train.json') as json_file:
    json_data = json.load(json_file)

# %%
from sklearn.model_selection import train_test_split

train, val = train_test_split(json_data['images'], test_size=0.2, random_state=42)

# %%
import copy

json_train = copy.deepcopy(json_data)
json_val = copy.deepcopy(json_data)

json_train['images'] = train
json_val['images'] = val

# %%
imgs = set(d['id'] for d in json_train['images'])
json_train['annotations']= [d for d in json_train['annotations'] if d['image_id'] in imgs]

imgs = set(d['id'] for d in json_val['images'])
json_val['annotations']= [d for d in json_val['annotations'] if d['image_id'] in imgs]

# %%
with open("train_split.json", "w") as json_file:
    json.dump(json_train, json_file)

with open("val_split.json", "w") as json_file:
    json.dump(json_val, json_file)
